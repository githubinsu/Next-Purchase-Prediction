# %%
import pandas as pd
import numpy as np

from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import f1_score
from skopt import BayesSearchCV
from skopt.space import Real, Integer

from tensorflow.keras.preprocessing.sequence import pad_sequences

from sklearn.preprocessing import LabelEncoder

# %%
pd.options.display.max_rows = 1000

# %%
df0 = pd.read_excel('train_data_LGBM.xlsx')

# %%
# 고객별 구매 빈도 확인 위한 pivoting
df_pivot = df0.pivot_table(index = 'Customer_ID', values = 'Product_No', aggfunc = 'count')

# %%
# 2번 이상 구매 고객 sorting, 이상치 제거
member_index = df_pivot[(df_pivot['Product_No'] > 1)&(df_pivot['Product_No'] < 5)].index
df = df0[df0['Customer_ID'].isin(member_index)]

# %%
# CTG, Sub_CTG 인코딩 및 datetime date numeric으로 변환
encoder1 = LabelEncoder()
encoder2 = LabelEncoder()

df.loc[:, 'CTG'] = encoder1.fit_transform(df['CTG'])
df.loc[:, 'Sub_CTG'] = encoder2.fit_transform(df['Sub_CTG'])

df.loc[:, 'Order_Date'] = pd.to_numeric(df['Order_Date'])
# Out:
# C:\Users\J13868\AppData\Local\Temp\ipykernel_20536\40206060.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'CTG'] = encoder1.fit_transform(df['CTG'])
# C:\Users\J13868\AppData\Local\Temp\ipykernel_20536\40206060.py:5: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'CTG'] = encoder1.fit_transform(df['CTG'])
# C:\Users\J13868\AppData\Local\Temp\ipykernel_20536\40206060.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'Sub_CTG'] = encoder2.fit_transform(df['Sub_CTG'])
# C:\Users\J13868\AppData\Local\Temp\ipykernel_20536\40206060.py:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'Sub_CTG'] = encoder2.fit_transform(df['Sub_CTG'])
# C:\Users\J13868\AppData\Local\Temp\ipykernel_20536\40206060.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'Order_Date'] = pd.to_numeric(df['Order_Date'])

# %%
# 각 고객의 구매 이력을 시계열 데이터로 변환
X = []
y = []
maxlen = 0
for member_id in df['Customer_ID'].unique():
    member_df = df[df['Customer_ID'] == member_id].sort_values('Order_Date')
    for i in range(len(member_df) - 1):
        X.append(member_df.iloc[:i+1][['Product_No', 'CTG', 'Sub_CTG' ]].values)
        y.append(member_df.iloc[i+1]['CTG'])
        maxlen = max(maxlen, i+1)

# 시계열 데이터를 동일한 길이로 패딩
X = pad_sequences(X, maxlen=maxlen, dtype='float32')
X[np.isnan(X)] = 0

# %%
# 데이터를 학습/테스트 세트로 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# LightGBM 모델 학습
model = LGBMClassifier(num_leaves=56,
                       min_data_in_leaf=30,
                       max_depth=7,
                       bagging_fraction=0.6,
                       feature_fraction=0.75,
                       random_state=0)
model.fit(X_train.reshape(X_train.shape[0], -1), y_train)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.75, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.75
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# LGBMClassifier(bagging_fraction=0.6, feature_fraction=0.75, max_depth=7,
#                min_data_in_leaf=30, num_leaves=56, random_state=0)

# %%
# 모델 평가
y_pred = model.predict(X_test.reshape(X_test.shape[0], -1))
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
# Out:
# Accuracy: 0.8045405405405406
# Precision: 0.7934750905805971
# Recall: 0.8045405405405406
# F1 Score: 0.7962918084295938

# %%
# 결과값 데이터 프레임 형태로 정리
results_df = pd.DataFrame(columns=['Customer_ID', 'Predicted_CTG'])

for member_id in df['Customer_ID'].unique():
    member_df = df[df['Customer_ID'] == member_id].sort_values('Order_Date')
    
    X2 = member_df[['Product_No','CTG', 'Sub_CTG']].values
    X2 = pad_sequences(X2[np.newaxis,:,:], maxlen=maxlen, dtype='float32')
    X2[np.isnan(X2)] = 0
    X2 = X2.reshape(1, -1)
    y_pred2 = model.predict(X2)
    
    results_df = pd.concat([results_df, pd.DataFrame({'Customer_ID': [member_id], 'Predicted_CTG': [y_pred2[0]]})], ignore_index=True)

# %%
# Sector별 구매빈도 데이터프레임 생성
Sector_df = pd.DataFrame(columns=['Customer_ID', 'A', 'B', 'C', 'D', 'E'])

for member_id in df['Customer_ID'].unique():
    member_df2 = df[df['Customer_ID'] == member_id].sort_values('Order_Date')
    
    sector_counts = member_df2['Sector'].value_counts()
    
    Sector_df = pd.concat([Sector_df, pd.DataFrame({
        'Customer_ID': [member_id],
        'A': [sector_counts.get('A', 0)],
        'B': [sector_counts.get('B', 0)],
        'C': [sector_counts.get('C', 0)],
        'D': [sector_counts.get('D', 0)],
        'E': [sector_counts.get('E', 0)]
    })], ignore_index=True)

# %%
summary_df = pd.merge(Sector_df,results_df, on = 'Customer_ID', how = 'inner')

# %%
summary_df['Predicted_CTG'] = summary_df['Predicted_CTG'].astype(int)
summary_df['Predicted_CTG'] = encoder1.inverse_transform(summary_df['Predicted_CTG'])

# %%
summary_df
# Out:
#       Customer_ID  A  B  C  D  E Predicted_CTG
# 0          972206  1  2  0  0  0            BA
# 1          180769  0  0  0  2  0            DA
# 2          263139  0  0  2  1  0            DA
# 3          117392  1  1  1  0  0            AA
# 4          534956  1  0  0  1  1            CC
# ...           ... .. .. .. .. ..           ...
# 15174      518530  3  0  0  0  0            AA
# 15175      830934  0  0  0  4  0            DA
# 15176      444315  0  0  2  0  0            CA
# 15177      906368  0  0  0  4  0            DA
# 15178      352930  0  0  3  0  0            CB
#
# [15179 rows x 7 columns]

# %%
# Bayes Search 통한 Hyper Parameter Fine Tuning

from skopt import BayesSearchCV
from skopt.space import Real, Integer

param_grid = {
    'num_leaves': Integer(7, 63),
    'min_data_in_leaf': Integer(1, 30),
    'max_depth': Integer(-1, 7),
    'bagging_fraction': Real(0.6, 0.9),
    'feature_fraction': Real(0.6, 0.9)
}

# 베이지안 최적화
model = LGBMClassifier(random_state=0)
bayes_search = BayesSearchCV(model, param_grid, cv=5)
bayes_search.fit(X_train.reshape(X_train.shape[0], -1), y_train)

best_params = bayes_search.best_params_
print('Best parameters:', best_params)

model = LGBMClassifier(**best_params)
model.fit(X_train.reshape(X_train.shape[0], -1), y_train)

y_pred = model.predict(X_test.reshape(X_test.shape[0], -1))
print('Accuracy:', accuracy_score(y_test, y_pred))
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.740272951846058, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.740272951846058
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] bagging_fraction is set=0.6455814781702842, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6455814781702842
# [LightGBM] [Warning] feature_fraction is set=0.740272951846058, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.740272951846058
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] bagging_fraction is set=0.6455814781702842, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6455814781702842
# [LightGBM] [Warning] feature_fraction is set=0.740272951846058, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.740272951846058
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] bagging_fraction is set=0.6455814781702842, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6455814781702842
# [LightGBM] [Warning] feature_fraction is set=0.740272951846058, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.740272951846058
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] bagging_fraction is set=0.6455814781702842, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6455814781702842
# [LightGBM] [Warning] feature_fraction is set=0.740272951846058, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.740272951846058
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] bagging_fraction is set=0.6455814781702842, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6455814781702842
# [LightGBM] [Warning] feature_fraction is set=0.7735939533961336, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7735939533961336
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] bagging_fraction is set=0.6388199329933814, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6388199329933814
# [LightGBM] [Warning] feature_fraction is set=0.7735939533961336, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7735939533961336
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] bagging_fraction is set=0.6388199329933814, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6388199329933814
# [LightGBM] [Warning] feature_fraction is set=0.7735939533961336, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7735939533961336
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] bagging_fraction is set=0.6388199329933814, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6388199329933814
# [LightGBM] [Warning] feature_fraction is set=0.7735939533961336, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7735939533961336
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] bagging_fraction is set=0.6388199329933814, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6388199329933814
# [LightGBM] [Warning] feature_fraction is set=0.7735939533961336, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7735939533961336
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] bagging_fraction is set=0.6388199329933814, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6388199329933814
# [LightGBM] [Warning] feature_fraction is set=0.789296227905811, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.789296227905811
# [LightGBM] [Warning] min_data_in_leaf is set=18, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=18
# [LightGBM] [Warning] bagging_fraction is set=0.8051385158694787, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8051385158694787
# [LightGBM] [Warning] feature_fraction is set=0.789296227905811, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.789296227905811
# [LightGBM] [Warning] min_data_in_leaf is set=18, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=18
# [LightGBM] [Warning] bagging_fraction is set=0.8051385158694787, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8051385158694787
# [LightGBM] [Warning] feature_fraction is set=0.789296227905811, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.789296227905811
# [LightGBM] [Warning] min_data_in_leaf is set=18, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=18
# [LightGBM] [Warning] bagging_fraction is set=0.8051385158694787, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8051385158694787
# [LightGBM] [Warning] feature_fraction is set=0.789296227905811, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.789296227905811
# [LightGBM] [Warning] min_data_in_leaf is set=18, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=18
# [LightGBM] [Warning] bagging_fraction is set=0.8051385158694787, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8051385158694787
# [LightGBM] [Warning] feature_fraction is set=0.789296227905811, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.789296227905811
# [LightGBM] [Warning] min_data_in_leaf is set=18, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=18
# [LightGBM] [Warning] bagging_fraction is set=0.8051385158694787, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8051385158694787
# [LightGBM] [Warning] feature_fraction is set=0.7880101573556108, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7880101573556108
# [LightGBM] [Warning] min_data_in_leaf is set=22, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=22
# [LightGBM] [Warning] bagging_fraction is set=0.8207406743339729, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8207406743339729
# [LightGBM] [Warning] feature_fraction is set=0.7880101573556108, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7880101573556108
# [LightGBM] [Warning] min_data_in_leaf is set=22, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=22
# [LightGBM] [Warning] bagging_fraction is set=0.8207406743339729, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8207406743339729
# [LightGBM] [Warning] feature_fraction is set=0.7880101573556108, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7880101573556108
# [LightGBM] [Warning] min_data_in_leaf is set=22, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=22
# [LightGBM] [Warning] bagging_fraction is set=0.8207406743339729, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8207406743339729
# [LightGBM] [Warning] feature_fraction is set=0.7880101573556108, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7880101573556108
# [LightGBM] [Warning] min_data_in_leaf is set=22, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=22
# [LightGBM] [Warning] bagging_fraction is set=0.8207406743339729, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8207406743339729
# [LightGBM] [Warning] feature_fraction is set=0.7880101573556108, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7880101573556108
# [LightGBM] [Warning] min_data_in_leaf is set=22, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=22
# [LightGBM] [Warning] bagging_fraction is set=0.8207406743339729, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8207406743339729
# [LightGBM] [Warning] feature_fraction is set=0.8568630859553035, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8568630859553035
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.7873128962437653, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7873128962437653
# [LightGBM] [Warning] feature_fraction is set=0.8568630859553035, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8568630859553035
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.7873128962437653, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7873128962437653
# [LightGBM] [Warning] feature_fraction is set=0.8568630859553035, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8568630859553035
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.7873128962437653, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7873128962437653
# [LightGBM] [Warning] feature_fraction is set=0.8568630859553035, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8568630859553035
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.7873128962437653, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7873128962437653
# [LightGBM] [Warning] feature_fraction is set=0.8568630859553035, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8568630859553035
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.7873128962437653, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7873128962437653
# [LightGBM] [Warning] feature_fraction is set=0.8124251026198397, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8124251026198397
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] bagging_fraction is set=0.7873790011612389, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7873790011612389
# [LightGBM] [Warning] feature_fraction is set=0.8124251026198397, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8124251026198397
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] bagging_fraction is set=0.7873790011612389, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7873790011612389
# [LightGBM] [Warning] feature_fraction is set=0.8124251026198397, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8124251026198397
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] bagging_fraction is set=0.7873790011612389, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7873790011612389
# [LightGBM] [Warning] feature_fraction is set=0.8124251026198397, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8124251026198397
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] bagging_fraction is set=0.7873790011612389, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7873790011612389
# [LightGBM] [Warning] feature_fraction is set=0.8124251026198397, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8124251026198397
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] bagging_fraction is set=0.7873790011612389, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7873790011612389
# [LightGBM] [Warning] feature_fraction is set=0.7601488415799678, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7601488415799678
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] bagging_fraction is set=0.6689467761959323, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6689467761959323
# [LightGBM] [Warning] feature_fraction is set=0.7601488415799678, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7601488415799678
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] bagging_fraction is set=0.6689467761959323, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6689467761959323
# [LightGBM] [Warning] feature_fraction is set=0.7601488415799678, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7601488415799678
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] bagging_fraction is set=0.6689467761959323, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6689467761959323
# [LightGBM] [Warning] feature_fraction is set=0.7601488415799678, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7601488415799678
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] bagging_fraction is set=0.6689467761959323, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6689467761959323
# [LightGBM] [Warning] feature_fraction is set=0.7601488415799678, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7601488415799678
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] bagging_fraction is set=0.6689467761959323, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6689467761959323
# [LightGBM] [Warning] feature_fraction is set=0.8152898749679524, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8152898749679524
# [LightGBM] [Warning] min_data_in_leaf is set=12, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=12
# [LightGBM] [Warning] bagging_fraction is set=0.7579414916734404, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7579414916734404
# [LightGBM] [Warning] feature_fraction is set=0.8152898749679524, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8152898749679524
# [LightGBM] [Warning] min_data_in_leaf is set=12, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=12
# [LightGBM] [Warning] bagging_fraction is set=0.7579414916734404, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7579414916734404
# [LightGBM] [Warning] feature_fraction is set=0.8152898749679524, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8152898749679524
# [LightGBM] [Warning] min_data_in_leaf is set=12, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=12
# [LightGBM] [Warning] bagging_fraction is set=0.7579414916734404, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7579414916734404
# [LightGBM] [Warning] feature_fraction is set=0.8152898749679524, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8152898749679524
# [LightGBM] [Warning] min_data_in_leaf is set=12, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=12
# [LightGBM] [Warning] bagging_fraction is set=0.7579414916734404, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7579414916734404
# [LightGBM] [Warning] feature_fraction is set=0.8152898749679524, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8152898749679524
# [LightGBM] [Warning] min_data_in_leaf is set=12, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=12
# [LightGBM] [Warning] bagging_fraction is set=0.7579414916734404, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7579414916734404
# [LightGBM] [Warning] feature_fraction is set=0.6809765269694632, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6809765269694632
# [LightGBM] [Warning] min_data_in_leaf is set=16, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=16
# [LightGBM] [Warning] bagging_fraction is set=0.7218927276215987, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7218927276215987
# [LightGBM] [Warning] feature_fraction is set=0.6809765269694632, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6809765269694632
# [LightGBM] [Warning] min_data_in_leaf is set=16, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=16
# [LightGBM] [Warning] bagging_fraction is set=0.7218927276215987, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7218927276215987
# [LightGBM] [Warning] feature_fraction is set=0.6809765269694632, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6809765269694632
# [LightGBM] [Warning] min_data_in_leaf is set=16, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=16
# [LightGBM] [Warning] bagging_fraction is set=0.7218927276215987, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7218927276215987
# [LightGBM] [Warning] feature_fraction is set=0.6809765269694632, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6809765269694632
# [LightGBM] [Warning] min_data_in_leaf is set=16, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=16
# [LightGBM] [Warning] bagging_fraction is set=0.7218927276215987, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7218927276215987
# [LightGBM] [Warning] feature_fraction is set=0.6809765269694632, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6809765269694632
# [LightGBM] [Warning] min_data_in_leaf is set=16, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=16
# [LightGBM] [Warning] bagging_fraction is set=0.7218927276215987, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7218927276215987
# [LightGBM] [Warning] feature_fraction is set=0.7783622741605392, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7783622741605392
# [LightGBM] [Warning] min_data_in_leaf is set=25, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=25
# [LightGBM] [Warning] bagging_fraction is set=0.653063111676917, subsample=1.0 will be ignored. Current value: bagging_fraction=0.653063111676917
# [LightGBM] [Warning] feature_fraction is set=0.7783622741605392, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7783622741605392
# [LightGBM] [Warning] min_data_in_leaf is set=25, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=25
# [LightGBM] [Warning] bagging_fraction is set=0.653063111676917, subsample=1.0 will be ignored. Current value: bagging_fraction=0.653063111676917
# [LightGBM] [Warning] feature_fraction is set=0.7783622741605392, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7783622741605392
# [LightGBM] [Warning] min_data_in_leaf is set=25, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=25
# [LightGBM] [Warning] bagging_fraction is set=0.653063111676917, subsample=1.0 will be ignored. Current value: bagging_fraction=0.653063111676917
# [LightGBM] [Warning] feature_fraction is set=0.7783622741605392, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7783622741605392
# [LightGBM] [Warning] min_data_in_leaf is set=25, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=25
# [LightGBM] [Warning] bagging_fraction is set=0.653063111676917, subsample=1.0 will be ignored. Current value: bagging_fraction=0.653063111676917
# [LightGBM] [Warning] feature_fraction is set=0.7783622741605392, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7783622741605392
# [LightGBM] [Warning] min_data_in_leaf is set=25, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=25
# [LightGBM] [Warning] bagging_fraction is set=0.653063111676917, subsample=1.0 will be ignored. Current value: bagging_fraction=0.653063111676917
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] min_data_in_leaf is set=25, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=25
# [LightGBM] [Warning] bagging_fraction is set=0.827153162461195, subsample=1.0 will be ignored. Current value: bagging_fraction=0.827153162461195
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] min_data_in_leaf is set=25, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=25
# [LightGBM] [Warning] bagging_fraction is set=0.827153162461195, subsample=1.0 will be ignored. Current value: bagging_fraction=0.827153162461195
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] min_data_in_leaf is set=25, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=25
# [LightGBM] [Warning] bagging_fraction is set=0.827153162461195, subsample=1.0 will be ignored. Current value: bagging_fraction=0.827153162461195
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] min_data_in_leaf is set=25, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=25
# [LightGBM] [Warning] bagging_fraction is set=0.827153162461195, subsample=1.0 will be ignored. Current value: bagging_fraction=0.827153162461195
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] min_data_in_leaf is set=25, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=25
# [LightGBM] [Warning] bagging_fraction is set=0.827153162461195, subsample=1.0 will be ignored. Current value: bagging_fraction=0.827153162461195
# [LightGBM] [Warning] feature_fraction is set=0.6184724603105152, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6184724603105152
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] bagging_fraction is set=0.7286631254510024, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7286631254510024
# [LightGBM] [Warning] feature_fraction is set=0.6184724603105152, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6184724603105152
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] bagging_fraction is set=0.7286631254510024, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7286631254510024
# [LightGBM] [Warning] feature_fraction is set=0.6184724603105152, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6184724603105152
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] bagging_fraction is set=0.7286631254510024, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7286631254510024
# [LightGBM] [Warning] feature_fraction is set=0.6184724603105152, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6184724603105152
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] bagging_fraction is set=0.7286631254510024, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7286631254510024
# [LightGBM] [Warning] feature_fraction is set=0.6184724603105152, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6184724603105152
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] bagging_fraction is set=0.7286631254510024, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7286631254510024
# [LightGBM] [Warning] feature_fraction is set=0.8919488198184822, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8919488198184822
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] bagging_fraction is set=0.678771799809037, subsample=1.0 will be ignored. Current value: bagging_fraction=0.678771799809037
# [LightGBM] [Warning] feature_fraction is set=0.8919488198184822, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8919488198184822
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] bagging_fraction is set=0.678771799809037, subsample=1.0 will be ignored. Current value: bagging_fraction=0.678771799809037
# [LightGBM] [Warning] feature_fraction is set=0.8919488198184822, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8919488198184822
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] bagging_fraction is set=0.678771799809037, subsample=1.0 will be ignored. Current value: bagging_fraction=0.678771799809037
# [LightGBM] [Warning] feature_fraction is set=0.8919488198184822, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8919488198184822
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] bagging_fraction is set=0.678771799809037, subsample=1.0 will be ignored. Current value: bagging_fraction=0.678771799809037
# [LightGBM] [Warning] feature_fraction is set=0.8919488198184822, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8919488198184822
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] bagging_fraction is set=0.678771799809037, subsample=1.0 will be ignored. Current value: bagging_fraction=0.678771799809037
# [LightGBM] [Warning] feature_fraction is set=0.883663801365148, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.883663801365148
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] bagging_fraction is set=0.6907059678704155, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6907059678704155
# [LightGBM] [Warning] feature_fraction is set=0.883663801365148, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.883663801365148
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] bagging_fraction is set=0.6907059678704155, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6907059678704155
# [LightGBM] [Warning] feature_fraction is set=0.883663801365148, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.883663801365148
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] bagging_fraction is set=0.6907059678704155, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6907059678704155
# [LightGBM] [Warning] feature_fraction is set=0.883663801365148, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.883663801365148
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] bagging_fraction is set=0.6907059678704155, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6907059678704155
# [LightGBM] [Warning] feature_fraction is set=0.883663801365148, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.883663801365148
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] bagging_fraction is set=0.6907059678704155, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6907059678704155
# [LightGBM] [Warning] feature_fraction is set=0.601041415445474, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.601041415445474
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] bagging_fraction is set=0.6422832799782151, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6422832799782151
# [LightGBM] [Warning] feature_fraction is set=0.601041415445474, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.601041415445474
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] bagging_fraction is set=0.6422832799782151, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6422832799782151
# [LightGBM] [Warning] feature_fraction is set=0.601041415445474, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.601041415445474
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] bagging_fraction is set=0.6422832799782151, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6422832799782151
# [LightGBM] [Warning] feature_fraction is set=0.601041415445474, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.601041415445474
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] bagging_fraction is set=0.6422832799782151, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6422832799782151
# [LightGBM] [Warning] feature_fraction is set=0.601041415445474, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.601041415445474
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] bagging_fraction is set=0.6422832799782151, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6422832799782151
# [LightGBM] [Warning] feature_fraction is set=0.6068800024236075, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6068800024236075
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.7908446093738586, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7908446093738586
# [LightGBM] [Warning] feature_fraction is set=0.6068800024236075, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6068800024236075
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.7908446093738586, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7908446093738586
# [LightGBM] [Warning] feature_fraction is set=0.6068800024236075, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6068800024236075
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.7908446093738586, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7908446093738586
# [LightGBM] [Warning] feature_fraction is set=0.6068800024236075, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6068800024236075
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.7908446093738586, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7908446093738586
# [LightGBM] [Warning] feature_fraction is set=0.6068800024236075, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6068800024236075
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.7908446093738586, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7908446093738586
# [LightGBM] [Warning] feature_fraction is set=0.6031432752795404, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6031432752795404
# [LightGBM] [Warning] min_data_in_leaf is set=24, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=24
# [LightGBM] [Warning] bagging_fraction is set=0.8981749509696655, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8981749509696655
# [LightGBM] [Warning] feature_fraction is set=0.6031432752795404, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6031432752795404
# [LightGBM] [Warning] min_data_in_leaf is set=24, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=24
# [LightGBM] [Warning] bagging_fraction is set=0.8981749509696655, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8981749509696655
# [LightGBM] [Warning] feature_fraction is set=0.6031432752795404, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6031432752795404
# [LightGBM] [Warning] min_data_in_leaf is set=24, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=24
# [LightGBM] [Warning] bagging_fraction is set=0.8981749509696655, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8981749509696655
# [LightGBM] [Warning] feature_fraction is set=0.6031432752795404, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6031432752795404
# [LightGBM] [Warning] min_data_in_leaf is set=24, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=24
# [LightGBM] [Warning] bagging_fraction is set=0.8981749509696655, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8981749509696655
# [LightGBM] [Warning] feature_fraction is set=0.6031432752795404, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6031432752795404
# [LightGBM] [Warning] min_data_in_leaf is set=24, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=24
# [LightGBM] [Warning] bagging_fraction is set=0.8981749509696655, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8981749509696655
# [LightGBM] [Warning] feature_fraction is set=0.6072387003225445, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6072387003225445
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.8156580841915937, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8156580841915937
# [LightGBM] [Warning] feature_fraction is set=0.6072387003225445, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6072387003225445
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.8156580841915937, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8156580841915937
# [LightGBM] [Warning] feature_fraction is set=0.6072387003225445, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6072387003225445
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.8156580841915937, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8156580841915937
# [LightGBM] [Warning] feature_fraction is set=0.6072387003225445, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6072387003225445
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.8156580841915937, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8156580841915937
# [LightGBM] [Warning] feature_fraction is set=0.6072387003225445, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6072387003225445
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.8156580841915937, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8156580841915937
# [LightGBM] [Warning] feature_fraction is set=0.6015944391768063, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6015944391768063
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.6208066814021155, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6208066814021155
# [LightGBM] [Warning] feature_fraction is set=0.6015944391768063, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6015944391768063
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.6208066814021155, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6208066814021155
# [LightGBM] [Warning] feature_fraction is set=0.6015944391768063, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6015944391768063
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.6208066814021155, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6208066814021155
# [LightGBM] [Warning] feature_fraction is set=0.6015944391768063, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6015944391768063
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.6208066814021155, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6208066814021155
# [LightGBM] [Warning] feature_fraction is set=0.6015944391768063, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6015944391768063
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.6208066814021155, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6208066814021155
# [LightGBM] [Warning] feature_fraction is set=0.6429842440606094, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6429842440606094
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6429842440606094, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6429842440606094
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6429842440606094, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6429842440606094
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6429842440606094, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6429842440606094
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6429842440606094, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6429842440606094
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.7148088134369834, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7148088134369834
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.7148088134369834, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7148088134369834
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.7148088134369834, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7148088134369834
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.7148088134369834, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7148088134369834
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.7148088134369834, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7148088134369834
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.6099347387615619, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6099347387615619
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] bagging_fraction is set=0.8526531614053026, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8526531614053026
# [LightGBM] [Warning] feature_fraction is set=0.6099347387615619, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6099347387615619
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] bagging_fraction is set=0.8526531614053026, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8526531614053026
# [LightGBM] [Warning] feature_fraction is set=0.6099347387615619, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6099347387615619
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] bagging_fraction is set=0.8526531614053026, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8526531614053026
# [LightGBM] [Warning] feature_fraction is set=0.6099347387615619, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6099347387615619
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] bagging_fraction is set=0.8526531614053026, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8526531614053026
# [LightGBM] [Warning] feature_fraction is set=0.6099347387615619, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6099347387615619
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] bagging_fraction is set=0.8526531614053026, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8526531614053026
# [LightGBM] [Warning] feature_fraction is set=0.6601495517866045, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6601495517866045
# ...
# [LightGBM] [Warning] feature_fraction is set=0.7888592435129036, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7888592435129036
# [LightGBM] [Warning] min_data_in_leaf is set=18, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=18
# [LightGBM] [Warning] bagging_fraction is set=0.7008333402587211, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7008333402587211
# [LightGBM] [Warning] feature_fraction is set=0.7888592435129036, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7888592435129036
# [LightGBM] [Warning] min_data_in_leaf is set=18, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=18
# [LightGBM] [Warning] bagging_fraction is set=0.7008333402587211, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7008333402587211
# [LightGBM] [Warning] feature_fraction is set=0.7888592435129036, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7888592435129036
# [LightGBM] [Warning] min_data_in_leaf is set=18, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=18
# [LightGBM] [Warning] bagging_fraction is set=0.7008333402587211, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7008333402587211
# [LightGBM] [Warning] feature_fraction is set=0.6037377734574991, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6037377734574991
# [LightGBM] [Warning] min_data_in_leaf is set=14, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=14
# [LightGBM] [Warning] bagging_fraction is set=0.6604555289669136, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6604555289669136
# [LightGBM] [Warning] feature_fraction is set=0.6037377734574991, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6037377734574991
# [LightGBM] [Warning] min_data_in_leaf is set=14, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=14
# [LightGBM] [Warning] bagging_fraction is set=0.6604555289669136, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6604555289669136
# [LightGBM] [Warning] feature_fraction is set=0.6037377734574991, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6037377734574991
# [LightGBM] [Warning] min_data_in_leaf is set=14, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=14
# [LightGBM] [Warning] bagging_fraction is set=0.6604555289669136, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6604555289669136
# [LightGBM] [Warning] feature_fraction is set=0.6037377734574991, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6037377734574991
# [LightGBM] [Warning] min_data_in_leaf is set=14, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=14
# [LightGBM] [Warning] bagging_fraction is set=0.6604555289669136, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6604555289669136
# [LightGBM] [Warning] feature_fraction is set=0.6037377734574991, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6037377734574991
# [LightGBM] [Warning] min_data_in_leaf is set=14, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=14
# [LightGBM] [Warning] bagging_fraction is set=0.6604555289669136, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6604555289669136
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] feature_fraction is set=0.6571996251622332, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6571996251622332
# [LightGBM] [Warning] min_data_in_leaf is set=27, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=27
# [LightGBM] [Warning] bagging_fraction is set=0.6150258927496421, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6150258927496421
# [LightGBM] [Warning] feature_fraction is set=0.6571996251622332, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6571996251622332
# [LightGBM] [Warning] min_data_in_leaf is set=27, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=27
# [LightGBM] [Warning] bagging_fraction is set=0.6150258927496421, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6150258927496421
# [LightGBM] [Warning] feature_fraction is set=0.6571996251622332, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6571996251622332
# [LightGBM] [Warning] min_data_in_leaf is set=27, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=27
# [LightGBM] [Warning] bagging_fraction is set=0.6150258927496421, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6150258927496421
# [LightGBM] [Warning] feature_fraction is set=0.6571996251622332, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6571996251622332
# [LightGBM] [Warning] min_data_in_leaf is set=27, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=27
# [LightGBM] [Warning] bagging_fraction is set=0.6150258927496421, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6150258927496421
# [LightGBM] [Warning] feature_fraction is set=0.6571996251622332, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6571996251622332
# [LightGBM] [Warning] min_data_in_leaf is set=27, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=27
# [LightGBM] [Warning] bagging_fraction is set=0.6150258927496421, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6150258927496421
# [LightGBM] [Warning] feature_fraction is set=0.8962107199601435, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8962107199601435
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.6025013646604129, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6025013646604129
# [LightGBM] [Warning] feature_fraction is set=0.8962107199601435, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8962107199601435
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.6025013646604129, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6025013646604129
# [LightGBM] [Warning] feature_fraction is set=0.8962107199601435, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8962107199601435
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.6025013646604129, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6025013646604129
# [LightGBM] [Warning] feature_fraction is set=0.8962107199601435, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8962107199601435
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.6025013646604129, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6025013646604129
# [LightGBM] [Warning] feature_fraction is set=0.8962107199601435, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8962107199601435
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.6025013646604129, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6025013646604129
# [LightGBM] [Warning] feature_fraction is set=0.7033497683499477, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7033497683499477
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] bagging_fraction is set=0.6222440758619024, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6222440758619024
# [LightGBM] [Warning] feature_fraction is set=0.7033497683499477, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7033497683499477
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] bagging_fraction is set=0.6222440758619024, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6222440758619024
# [LightGBM] [Warning] feature_fraction is set=0.7033497683499477, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7033497683499477
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] bagging_fraction is set=0.6222440758619024, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6222440758619024
# [LightGBM] [Warning] feature_fraction is set=0.7033497683499477, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7033497683499477
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] bagging_fraction is set=0.6222440758619024, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6222440758619024
# [LightGBM] [Warning] feature_fraction is set=0.7033497683499477, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7033497683499477
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] bagging_fraction is set=0.6222440758619024, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6222440758619024
# [LightGBM] [Warning] feature_fraction is set=0.6802725387186539, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6802725387186539
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6802725387186539, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6802725387186539
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6802725387186539, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6802725387186539
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6802725387186539, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6802725387186539
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6802725387186539, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6802725387186539
# [LightGBM] [Warning] min_data_in_leaf is set=1, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=1
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.6072387003225445, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6072387003225445
# [LightGBM] [Warning] min_data_in_leaf is set=30, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=30
# [LightGBM] [Warning] bagging_fraction is set=0.8156580841915937, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8156580841915937
# Best parameters: OrderedDict([('bagging_fraction', 0.8156580841915937), ('feature_fraction', 0.6072387003225445), ('max_depth', 5), ('min_data_in_leaf', 30), ('num_leaves', 40)])
# Accuracy: 0.8069189189189189
